# %% [markdown]
# # Digitális Labor Hangfeldolgozás 1 (részlet)

# %% [markdown]
# ## Bevezetés

# %% [markdown]
# A hang a levegőben terjedő longitudinális sűrűséghullám, melyet mikrofonnal rögzítünk. A mikrofonok fő alkatrésze egy membrán, mely képes
# a levegőrezgéseit átvenni és azt egy másik alkatrésznek továbbítani, mely
# azokat elektromos jellé alakítja oly módon, hogy a jel feszültsége megfelel a
# mikrofon membránjára nehezedő pillanatnyi nyomásnak...

# %% [markdown]
# # ( Nagy ugrás)

# %%
# %pylab inline
import scipy
import scipy.signal as signal
import hanglab
import ipywidgets
import matplotlib.pylab as plt 
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt', 'f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Hangminta generálása

# %% [markdown]
# Hangfájlt nem csak a hangkártya bemenetéről rögzíthetünk, hanem programból is generálhatunk. Az alábbi program egy 2 s-os, 1 kHz-es szinuszjelet állít elő, és ment fájlba. A programban szereplő SAMPLE_RATE változó a mintavételezési frekvenciát tárolja, a beállított értéke 44100.

# %%
length = 2
f = 1000
t = linspace(0, length, length * hanglab.SAMPLE_RATE)
sinwave = cos(t * f * numpy.pi)
sinwave = reshape(sinwave, [1, t.size])  # a hangfájl mindig 2-dimenziós tömb!
hanglab.plotwave(sinwave, xlim=[1.0,1.02])
hanglab.writewave('sinus.wav', sinwave)

# %% [markdown]
# Módosítsunk a fenti programon úgy, hogy a generált szinuszhullám frekvenciája folyamatosan változzon 100 Hz és 5 kHz között! Mentsük el a generált hangot chirp.wav néven, majd játsszuk le!

# %%
f=[]
for x in range(len(t)):
    f.append(100+(5000-100)*x/len(t))
chirp = cos(t * f * numpy.pi)
chirp = reshape(chirp, [1, t.size])  # a hangfájl mindig 2-dimenziós tömb!
hanglab.plotwave(chirp, xlim=[0,0.2])
hanglab.writewave('chirp.wav', chirp)

# %% [markdown]
# A kapott ábránkon látszik, hogy nagyon besűrűsödik és a kapott fájl hangja kifejezetten fűlsüketítő

# %% [markdown]
# ## Köszönöm a figyelmet
